# %% [markdown]
# # Ejercicios para el primer examen
# # Alejandro Reyes Romero
# ## Geofísica Matemática y Computacional
#
# - Prof. Luis Miguel de la Cruz Salas
# - Rev: sáb oct  3 19:11:26 CDT 2020

# %% [markdown]
# ## Ejercicio 1.
# Las ecuaciones siguientes tienen una solución en los intervalos que se mencionan:
#
# 1. $x \cos(x) - 2x^2 + 3x - 1 = 0$ en $[0.2, 0.3]$ y $[1.2, 1.3]$
# 2. $(x-2)^2 - \ln(x) = 0$ en $[1,2]$ y $[e, 4]$
# 3. $2^x \cos(2x)-(x-2)^2 = 0$ en $[2,3]$ y $[3,4]$
# 4. $x - (\ln(x))^x = 0 $ en $[4,5]$
#
# **Realice lo siguiente**:
# - Use el teorema del valor intermedio para mostrar que la solución existe en cada intervalo mencionado.
# - Gráfique la función usando el código de la celda siguiente y:
#     - Modifique la función a ser evaluada ($y$).
#     - Modifique el dominio de graficación de la función ($x$).
#     - Modifique los extremos del intervalo a evaluar ($A$ y $B$).

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Función a ser evaluada
y = lambda x: x * np.cos(x)-2 * x**2 + 3 * x - 1

# Dominio de la función
xmin = 0
xmax = 2
x = np.linspace(xmin, xmax, 100)

A = 1.2  # Extremo izquierdo del intervalo
B = 1.3  # Extremo derecho del intervalo

# Gráfica de la función
plt.plot(x,y(x), 'r-', lw=2)

# Líneas verticales en los extremos del intervalo y línea en y = 0
ymin = np.min(y(x))
ymax = np.max(y(x))
plt.plot([A,A], [ymin,ymax], 'g--', lw=1)
plt.plot([B,B], [ymin,ymax], 'g--', lw=1)
plt.plot([xmin, xmax], [0,0], 'b-', lw=1)

plt.grid()
plt.show()

# %%
# Función a ser evaluada
y = lambda x: (x - 2) ** 2 - np.log(x)

# Dominio de la función
xmin = 0.1
xmax = 5
x = np.linspace(xmin, xmax, 100)

A = np.exp(1) # Extremo izquierdo del intervalo
B = 4  # Extremo derecho del intervalo

# Gráfica de la función
plt.plot(x,y(x), 'r-', lw=2)

# Líneas verticales en los extremos del intervalo y línea en y = 0
ymin = np.min(y(x))
ymax = np.max(y(x))
plt.plot([A,A], [ymin,ymax], 'g--', lw=1)
plt.plot([B,B], [ymin,ymax], 'g--', lw=1)
plt.plot([xmin, xmax], [0,0], 'b-', lw=1)

plt.grid()
plt.show()

# %%
# Función a ser evaluada
y = lambda x: 2 ** x *np.cos(2*x)-(x - 2) ** 2

# Dominio de la función
xmin = 1
xmax = 5
x = np.linspace(xmin, xmax, 100)

A = 3  # Extremo izquierdo del intervalo
B = 4  # Extremo derecho del intervalo

# Gráfica de la función
plt.plot(x,y(x), 'r-', lw=2)

# Líneas verticales en los extremos del intervalo y línea en y = 0
ymin = np.min(y(x))
ymax = np.max(y(x))
plt.plot([A,A], [ymin,ymax], 'g--', lw=1)
plt.plot([B,B], [ymin,ymax], 'g--', lw=1)
plt.plot([xmin, xmax], [0,0], 'b-', lw=1)

plt.grid()
plt.show()

# %%
# Función a ser evaluada
y = lambda x: x-((np.log(x))**x)

# Dominio de la función
xmin = 1
xmax = 6
x = np.linspace(xmin, xmax, 100)

A = 4  # Extremo izquierdo del intervalo
B = 5  # Extremo derecho del intervalo

# Gráfica de la función
plt.plot(x,y(x), 'r-', lw=2)

# Líneas verticales en los extremos del intervalo y línea en y = 0
ymin = np.min(y(x))
ymax = np.max(y(x))
plt.plot([A,A], [ymin,ymax], 'g--', lw=1)
plt.plot([B,B], [ymin,ymax], 'g--', lw=1)
plt.plot([xmin, xmax], [0,0], 'b-', lw=1)

plt.grid()
plt.show()

# %% [markdown]
# ## Ejercicio 2.
# Calcular el segundo polinomio de Taylor $P_2(x)$ de la función $f(x) = e^x \cos(x)$ alrededor de $x_0 = 0$, así como el error $R_2(x)$ de acuerdo con el Teorema de Taylor.
#
# **Realice lo siguiente**:
#
# - Aproximar $f(x)$ usando $P_2(x)$ en $x = 0.5$ y calcular el error absoluto y relativo de la aproximación.
# - ¿Cómo se compara el error absoluto con la fórmula del error $R_2(x)$? **Hint**: encuentre una cota máxima de $R_2(x)$ en $[0,0.5]$.
# - Encuentre una cota para $R_2(x)$ en el intervalo $[0,1]$.
# - Aproximar la integral $\int_0^1 f(x) dx$ usando $\int_0^1 P_2(x) dx$.
# - Calcule la integral exacta de $\int_0^1 f(x) dx$ y compare con el error absoluto de la aproximación anterior. ¿Cómo se compara este resultado con el error calculado de la siguiente manera $\int_0^1 |R_2(x)| dx$?
# - Haga una gráfica de $f(x)$ y $P_2(x)$ en el intervalo $[0, 0.5]$. Decore la gráfica con una leyenda para cada una de las curvas, etiqueta en los ejes, y un título que diga: "$|f(0.5)-P_2(0.5)| = E_a$" donde $E_a$ es el error absoluto en $x=0.5$.

# %%
#funcion a ser evaluada
f=lambda x: np.exp(x) * np.cos(x)
#Polinomio de segundo grado de la funcion
P_2= lambda x: np.exp(x) * (np.cos(x)+( x * (np.cos(x) *-np.sin(x))))
#Expresión del error del polinomio de segundo grado
R2=lambda x: (1/24)*np.fabs(np.exp(x)*(np.cos(x)-np.sin(x)))
x = np.linspace(0, 0.5, 20)
Ea= np.fabs(f(0.5)-P_2(0.5))
Er=Ea/np.fabs(f(0.5))
print ('Error absoluto={:.20f}'.format(Ea))
print ('Error relativo={:.20f}'.format(Er))
Ea=np.fabs(Ea-R2(0.5))
print ('Comparación del error con la cota máxima ={:.20f}'.format(Ea))

#Cota para el intervalo [0 1]
Cota=R2(1)

#Integral aproximada:
Int=lambda x: x*np.exp(x)*np.cos(x)
AI=Int(1)-Int(0)

#Integral Exacta:
Ex=lambda x:(np.exp(x)*(np.sin(x)+np.cos(x)))/2
EI=Ex(1)-Ex(0)

#Integral del error:
CotaI=lambda x: np.fabs(Cota*x)
CI=CotaI(1)-CotaI(0)
Ea=np.fabs(EI-AI)
print ('Error absoluto={:.20f}'.format(Ea))

#Comparación
C=np.fabs(Ea-CI)
print ('Diferencia entre error de derivada y error de cotas={:.20f}'.format(C))


# Gráfica de la función
plt.plot(x,f(x), 'r-', lw=2, label='$f(x)$')
plt.plot(x,P_2(x), 'g-', lw=2, label='$P_2(x)$')
plt.title('|$f$(0.5)−$P_2$(0.5)|=$E_a$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()
# Out:
# Error absoluto=0.34683777783244096327
# Error relativo=0.23971276930210155820
# Comparación del error con la cota máxima =0.31948569644200119910
# Error absoluto=0.09066932636852143013
# Diferencia entre error de derivada y error de cotas=0.05655843689923155393

# %% [markdown]
# ## Ejercicio 3.
# Calcular el error absoluto y relativo de las siguientes aproximaciones:
# - $p = \pi, pa = 3.1416$
# - $p = e, pa = 2.718$
# - $p = 8!, pa = 39900$
# - $p = \sqrt{2}, pa = 1.4142$
# - $p = \sqrt{2}, pa = 1.414213$
# - $p = \frac{4}{5} + \frac{1}{3}, pa = round(p,3)$
# - $p = \frac{1}{3}-\frac{3}{11}+\frac{3}{20}, pa = round(p,3)$
# - $p = \frac{1}{3}-\frac{3}{11}+\frac{3}{20}, pa =$ truncamiento de $p$ a $3$ dígitos.

# %%
Ea= np.fabs(np.pi-3.1416)
Er=Ea/np.fabs(np.pi)
print ('Error absoluto={:.20f}'.format(Ea))
print ('Error relativo={:.20f}'.format(Er))
# Out:
# Error absoluto=0.00000734641020683213
# Error relativo=0.00000233843499679617

# %%
Ea= np.fabs(np.exp(1)-2.718)
Er=Ea/np.fabs(np.exp(1))
print ('Error absoluto={:.20f}'.format(Ea))
print ('Error relativo={:.20f}'.format(Er))
# Out:
# Error absoluto=0.00028182845904511922
# Error relativo=0.00010367889601972718

# %%
Ea= np.fabs(np.math.factorial(8)-39900)
Er=Ea/np.fabs(np.math.factorial(8))
print ('Error absoluto={:.20f}'.format(Ea))
print ('Error relativo={:.20f}'.format(Er))
# Out:
# Error absoluto=420.00000000000000000000
# Error relativo=0.01041666666666666609

# %%
Ea= np.fabs((4/5+1/3)-round(4/5+1/3,3))
Er=Ea/np.fabs(4/5+1/3)
print ('Error absoluto={:.20f}'.format(Ea))
print ('Error relativo={:.20f}'.format(Er))
# Out:
# Error absoluto=0.00033333333333329662
# Error relativo=0.00029411764705879114

# %%
Ea= np.fabs((1/3-3/11+3/20)-round(1/3-3/11+3/20,3))
Er=Ea/np.fabs(1/3-3/11+3/20)
print ('Error absoluto={:.20f}'.format(Ea))
print ('Error relativo={:.20f}'.format(Er))
# Out:
# Error absoluto=0.00039393939393939092
# Error relativo=0.00187050359712228795

# %%
val = float('%.3f'%(1/3-3/11+3/20))
Ea= np.fabs((1/3-3/11+3/20)-val)        
Er=Ea/np.fabs(1/3-3/11+3/20)
print ('Error absoluto={:.20f}'.format(Ea))
print ('Error relativo={:.20f}'.format(Er))
# Out:
# Error absoluto=0.00039393939393939092
# Error relativo=0.00187050359712228795

# %% [markdown]
# ## Ejercicio 4.
# Suponga que tenemos dos puntos en el plano Cartesiano $(x_0, y_0)$ y $(x_1, y_1)$ con $y_0 \neq y_1$. Las siguientes dos fórmulas calculan en dónde es que esta línea cruza al eje $x$:
# $$
# x = \frac{x_0y_1 - x_1y_0}{y_1-y_0}
# \quad \quad \text{y} \quad \quad
# x = x_0 - \frac{(x_1 - x_0)y_0}{y_1-y_0}
# $$
#
# **Realizar lo siguiente**:
# - Mostrar que ambas fórmulas son equivalentes. **Hint**: calcular la fórmula de la recta que pasa por ambos puntos y luego evaluarla cuando $y=0$ y despejar $x$.
# - Usar los siguientes datos $(x_0, y_0) = (1.31, 3.24)$ y $(x_1, y_1) = (1.93, 4.76)$ y una aritmética de redondeo a 6 dígitos para calcular $x$ usando las dos fórmulas anteriores. ¿Puede determinar cuál de las dos fórmulas es mejor y por qué?
#
# **Hint**: Evalue primero usando la precisión por omisión:
# ```python
# # Primera fórmula
# def f1(x0,y0,x1,y1):
#     return (x0*y1 - x1*y0) /(y1 - y0)
# # Segunda fórmula
# def f2(x0,y0,x1,y1):
#     return x0 - (x1 - x0)*y0 /(y1 - y0)
# # Evaluación sin redondeo
# f1_e = f1(1.31,3.24,1.93,4.76)
# f2_e = f2(1.31,3.24,1.93,4.76)
# print('f1 = {:.55f}'.format(f1_e))
# print('f2 = {:.55f}'.format(f2_e))
# ```
# Posteriormente evalue usando redondeo:
#
# ```python
# # Usamos las siguiente bibliotecas para redondear
# from decimal import getcontext, Decimal
# getcontext().prec=6 # precisión a 6 dígitos
# print(getcontext())
# # Evaluamos con redondeo
# (x0, y0) = (Decimal(1.31),Decimal(3.24))
# (x1, y1) = (Decimal(1.93),Decimal(4.76))
# print('\n {:.6f} \t {:.6f} \t {:.6f} \t {:.6f} \n'.format(x0,y0,x1,y1))
# f1_a = f1(x0,y0,x1,y1)
# f2_a = f2(x0,y0,x1,y1)
# print('f1 = {:.10f}'.format(f1_a))
# print('f2 = {:.10f}'.format(f2_a))
# ```
# Ahora calcule el error absoluto y relativo comparando con los primeros resultados.
#
# ```python
# E1_a = np.fabs(f1_e - float(f1_a))
# E2_a = np.fabs(f2_e - float(f2_a))
# E1_r = E1_a / np.fabs(f1_e)
# E2_r = E2_a / np.fabs(f2_e)
# print('Error absoluto f1: {:.55f}'.format(E1_a))
# print('Error absoluto f2: {:.55f}'.format(E2_a))
# print('Error relativo f1: {:.55f}'.format(E1_r))
# print('Error relativo f2: {:.55f}'.format(E2_r))
# ```

# %%
def f1(x0,y0,x1,y1):
    return (x0*y1 - x1*y0) /(y1 - y0)
# Segunda fórmula
def f2(x0,y0,x1,y1):
    return x0 - (x1 - x0)*y0 /(y1 - y0)

# Evaluación sin redondeo
f1_e = f1(1.31,3.24,1.93,4.76)
f2_e = f2(1.31,3.24,1.93,4.76)
print('f1 = {:.55f}'.format(f1_e))
print('f2 = {:.55f}'.format(f2_e))

# Usamos las siguiente bibliotecas para redondear
from decimal import getcontext, Decimal 
getcontext().prec=6 # precisión a 6 dígitos
print(getcontext())
# Evaluamos con redondeo
(x0, y0) = (Decimal(1.31),Decimal(3.24))
(x1, y1) = (Decimal(1.93),Decimal(4.76))
print('\n {:.6f} \t {:.6f} \t {:.6f} \t {:.6f} \n'.format(x0,y0,x1,y1))
f1_a = f1(x0,y0,x1,y1)
f2_a = f2(x0,y0,x1,y1)
print('f1 = {:.10f}'.format(f1_a))
print('f2 = {:.10f}'.format(f2_a))

E1_a = np.fabs(f1_e - float(f1_a))
E2_a = np.fabs(f2_e - float(f2_a))
E1_r = E1_a / np.fabs(f1_e)
E2_r = E2_a / np.fabs(f2_e)
print('Error absoluto f1: {:.55f}'.format(E1_a))
print('Error absoluto f2: {:.55f}'.format(E2_a))
print('Error relativo f1: {:.55f}'.format(E1_r))
print('Error relativo f2: {:.55f}'.format(E2_r))
# Out:
# f1 = -0.0115789473684215337562219971800914208870381116867065430
# f2 = -0.0115789473684213550797039715689606964588165283203125000
# Context(prec=6, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[InvalidOperation, DivisionByZero, Overflow])
#
#  1.310000 	 3.240000 	 1.930000 	 4.760000
#
# f1 = -0.0115789000
# f2 = -0.0115800000
# Error absoluto f1: 0.0000000473684215341468872750851915043313056230545043945
# Error absoluto f2: 0.0000010526315786449358391507757914951071143150329589844
# Error relativo f1: 0.0000040909091324943341094256578360788267900716164149344
# Error relativo f2: 0.0000909090908829693561746254637512265617260709404945374

# %% [markdown]
# ## Ejercicio 5.
# La secuencia $\{F_n\}$ descrita por $F_0 = 1, F_1 = 1$, y $F_{n+2}$ = $F_n + F_{n+1}$, si $n \geq 0$, se conoce como la secuencia de Fibonacci. Sus términos ocurren naturalmente en especies botánicas, particularmente en aquellas con pétalos o escalas que se arreglan en forma de espiral logarítmica.
#
# Considere la secuencia $\{x_n\}$, donde $x_n = F_{n+1} / F_n$. El límite
# $\lim_{n \to \infty} x_n = x$ existe y es:
# $$
# \displaystyle x = \frac{1 + \sqrt{5}}{2} \quad \text{(golden ratio)}
# $$
# Escribir un algoritmo para aproximar $x$ y dada una $n$, calcular el error absoluto y el error relativo de la aproximación. Grafique la secuencia $x$.
#
# **Hint**: calcule los números de Fibonacci y posteriormente la secuencia $x_n$.

# %%
def fib(n):
    a, b = 1,1
    for i in range(n-1):
        a, b = b, a + b
    return a

y=[]
for i in range(0,50):
    xn=fib(i+1)/fib(i)
    Ea=np.fabs(((1+np.sqrt(5))/2)-xn)
    print('Dado n =',i)
    print('Error absoluto: {:.55f}'.format(Ea))
    Er=Ea/np.fabs((1+np.sqrt(5))/2)
    print('Error relativo: {:.55f}'.format(Er))
    y.append(xn)
x=np.linspace(0,50)
plt.plot(x,y)
plt.title('Secuencia $x_n$')
plt.show()
# Out:
# Dado n = 0
# Error absoluto: 0.6180339887498949025257388711906969547271728515625000000
# Error relativo: 0.3819660112501051529854123600671300664544105529785156250
# Dado n = 1
# Error absoluto: 0.6180339887498949025257388711906969547271728515625000000
# Error relativo: 0.3819660112501051529854123600671300664544105529785156250
# Dado n = 2
# Error absoluto: 0.3819660112501050974742611288093030452728271484375000000
# Error relativo: 0.2360679774997896662735996642368263565003871917724609375
# Dado n = 3
# Error absoluto: 0.1180339887498949025257388711906969547271728515625000000
# Error relativo: 0.0729490168751577572336941557296086102724075317382812500
# Dado n = 4
# Error absoluto: 0.0486326779167718381557961038197390735149383544921875000
# Error relativo: 0.0300566479164914232558025730668305186554789543151855469
# Dado n = 5
# Error absoluto: 0.0180339887498948137078969011781737208366394042968750000
# Error relativo: 0.0111456180001682208374758076274702034424990415573120117
# Dado n = 6
# Error absoluto: 0.0069660112501050974742611288093030452728271484375000000
# Error relativo: 0.0043052317185790943063206093199823953909799456596374512
# Dado n = 7
# Error absoluto: 0.0026493733652794837496458058012649416923522949218750000
# Error relativo: 0.0016374027886314115182164741213455272372812032699584961
# Dado n = 8
# Error absoluto: 0.0010136302977241662404139788122847676277160644531250000
# Error relativo: 0.0006264579760202099341370729490563462604768574237823486
# Dado n = 9
# Error absoluto: 0.0003869299263654646381382917752489447593688964843750000
# Error relativo: 0.0002391358457583512046266266404259681621624622493982315
# Dado n = 10
# Error absoluto: 0.0001478294319232631437444069888442754745483398437500000
# Error relativo: 0.0000913636134661653578209472570392790657933801412582397
# Dado n = 11
# Error absoluto: 0.0000564606600073069841982942307367920875549316406250000
# Error relativo: 0.0000348946069117676022238415389775667563299066387116909
# Dado n = 12
# Error absoluto: 0.0000215668056606777014394538127817213535308837890625000
# Error relativo: 0.0000133290189270624512464123376243030349996843142434955
# Dado n = 13
# Error absoluto: 0.0000082376769334757682372583076357841491699218750000000
# Error relativo: 0.0000050911643332290306784935346451348436858097556978464
# Dado n = 14
# Error absoluto: 0.0000031465286196574737687114975415170192718505859375000
# Error relativo: 0.0000019446616335226094208392735862567235471942694857717
# Dado n = 15
# Error absoluto: 0.0000012018646489142525979332276619970798492431640625000
# Error relativo: 0.0000007427932029059675056212428030655292587880467181094
# Dado n = 16
# Error absoluto: 0.0000004590717870289751090240315534174442291259765625000
# Error relativo: 0.0000002837219676600597320612648193083327186059250379913
# Dado n = 17
# Error absoluto: 0.0000001753497695933248223809641785919666290283203125000
# Error relativo: 0.0000001083721175281375629570536117847467938446470725466
# Dado n = 18
# Error absoluto: 0.0000000669776591966098067132406868040561676025390625000
# Error relativo: 0.0000000413944698704118380204344893741330579928217048291
# Dado n = 19
# Error absoluto: 0.0000000255831884565793643560027703642845153808593750000
# Error relativo: 0.0000000158112800067600094976520924781177024343037373910
# Dado n = 20
# Error absoluto: 0.0000000097719083935743356050807051360607147216796875000
# Error relativo: 0.0000000060393715221793241108526114767525438953299499190
# Dado n = 21
# Error absoluto: 0.0000000037325369461882473842706531286239624023437500000
# Error relativo: 0.0000000023068346970090739653511704006184565574066880345
# Dado n = 22
# Error absoluto: 0.0000000014257022229458016226999461650848388671875000000
# Error relativo: 0.0000000008811324316167856207797055853397048819086734284
# Dado n = 23
# Error absoluto: 0.0000000005445699446937624088604934513568878173828125000
# Error relativo: 0.0000000003365627350723956300958116253703054573942488048
# Dado n = 24
# Error absoluto: 0.0000000002080071670462757538189180195331573486328125000
# Error relativo: 0.0000000001285554991381754930992690434465386753459803515
# Dado n = 25
# Error absoluto: 0.0000000000794517784896697776275686919689178466796875000
# Error relativo: 0.0000000000491038995732437050944829507790034264433365330
# Dado n = 26
# Error absoluto: 0.0000000000303477243335237290011718869209289550781250000
# Error relativo: 0.0000000000187559251193299136303791850563502433511808842
# Dado n = 27
# Error absoluto: 0.0000000000115918386001112594385631382465362548828125000
# Error relativo: 0.0000000000071641502469717588907394332578582615920353982
# Dado n = 28
# Error absoluto: 0.0000000000044275694222051242832094430923461914062500000
# Error relativo: 0.0000000000027363883904725002831063498638449293215955949
# Dado n = 29
# Error absoluto: 0.0000000000016913137557139634736813604831695556640625000
# Error relativo: 0.0000000000010452893866714660624064038843825952815932284
# Dado n = 30
# Error absoluto: 0.0000000000006459277557269160752184689044952392578125000
# Error relativo: 0.0000000000003992053073161736488247804361625209752903638
# Dado n = 31
# Error absoluto: 0.0000000000002466915560717097832821309566497802734375000
# Error relativo: 0.0000000000001524637663899171379297229360370242841012968
# Dado n = 32
# Error absoluto: 0.0000000000000941469124882132746279239654541015625000000
# Error relativo: 0.0000000000000581859918535777397208394048761741038382125
# Dado n = 33
# Error absoluto: 0.0000000000000359712259978550719097256660461425781250000
# Error relativo: 0.0000000000000222314402836782846074828563787991208861462
# Dado n = 34
# Error absoluto: 0.0000000000000137667655053519411012530326843261718750000
# Error relativo: 0.0000000000000085083289974571219902182164703413129375117
# Dado n = 35
# Error absoluto: 0.0000000000000053290705182007513940334320068359375000000
# Error relativo: 0.0000000000000032935467086930793910195299796953043970674
# Dado n = 36
# Error absoluto: 0.0000000000000019984014443252817727625370025634765625000
# Error relativo: 0.0000000000000012350800157599047223285171660725013106672
# Dado n = 37
# Error absoluto: 0.0000000000000008881784197001252323389053344726562500000
# Error relativo: 0.0000000000000005489244514488465323007172790737255073559
# Dado n = 38
# Error absoluto: 0.0000000000000002220446049250313080847263336181640625000
# Error relativo: 0.0000000000000001372311128622116330751793197684313768390
# Dado n = 39
# Error absoluto: 0.0000000000000002220446049250313080847263336181640625000
# Error relativo: 0.0000000000000001372311128622116330751793197684313768390
# Dado n = 40
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
# Dado n = 41
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
# Dado n = 42
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
# Dado n = 43
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
# Dado n = 44
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
# Dado n = 45
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
# Dado n = 46
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
# Dado n = 47
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
# Dado n = 48
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
# Dado n = 49
# Error absoluto: 0.0000000000000000000000000000000000000000000000000000000
# Error relativo: 0.0000000000000000000000000000000000000000000000000000000
